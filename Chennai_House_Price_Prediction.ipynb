# %% [markdown]
# #Data Preprocessing

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import plotly.express as px

# %%
train = pd.read_csv("/content/train-chennai-sale.csv")

# %%
train.head()
# Out:
#    PRT_ID        AREA  INT_SQFT   DATE_SALE  DIST_MAINROAD  N_BEDROOM  \
# 0  P03210  Karapakkam      1004  04-05-2011            131        1.0
# 1  P09411  Anna Nagar      1986  19-12-2006             26        2.0
# 2  P01812       Adyar       909  04-02-2012             70        1.0
# 3  P05346   Velachery      1855  13-03-2010             14        3.0
# 4  P06210  Karapakkam      1226  05-10-2009             84        1.0
#
#    N_BATHROOM  N_ROOM SALE_COND PARK_FACIL  ... UTILITY_AVAIL  STREET MZZONE  \
# 0         1.0       3  AbNormal        Yes  ...        AllPub   Paved      A
# 1         1.0       5  AbNormal         No  ...        AllPub  Gravel     RH
# 2         1.0       3  AbNormal        Yes  ...           ELO  Gravel     RL
# 3         2.0       5    Family         No  ...       NoSewr    Paved      I
# 4         1.0       3  AbNormal        Yes  ...        AllPub  Gravel      C
#
#   QS_ROOMS QS_BATHROOM  QS_BEDROOM  QS_OVERALL  REG_FEE  COMMIS  SALES_PRICE
# 0      4.0         3.9         4.9       4.330   380000  144400      7600000
# 1      4.9         4.2         2.5       3.765   760122  304049     21717770
# 2      4.1         3.8         2.2       3.090   421094   92114     13159200
# 3      4.7         3.9         3.6       4.010   356321   77042      9630290
# 4      3.0         2.5         4.1       3.290   237000   74063      7406250
#
# [5 rows x 22 columns]

# %%
train.isna().sum()
# Out:
# PRT_ID            0
# AREA              0
# INT_SQFT          0
# DATE_SALE         0
# DIST_MAINROAD     0
# N_BEDROOM         1
# N_BATHROOM        5
# N_ROOM            0
# SALE_COND         0
# PARK_FACIL        0
# DATE_BUILD        0
# BUILDTYPE         0
# UTILITY_AVAIL     0
# STREET            0
# MZZONE            0
# QS_ROOMS          0
# QS_BATHROOM       0
# QS_BEDROOM        0
# QS_OVERALL       48
# REG_FEE           0
# COMMIS            0
# SALES_PRICE       0
# dtype: int64

# %%
#Filling Nan Values
train['N_BEDROOM']=train['N_BEDROOM'].fillna(train['N_BEDROOM'].mean())
train['N_BATHROOM']=train['N_BATHROOM'].fillna(train['N_BATHROOM'].mean())
train['QS_OVERALL']=train['QS_OVERALL'].fillna(train['QS_OVERALL'].mean())

# %% [markdown]
# #Fixing Categorical Features

# %%
train = train.replace(to_replace=['Anna Nagar','Ann Nagar','Ana Nagar'],value='Anna Nagar')
train = train.replace(to_replace=['Adyr','Adyar'],value='Adyar')
train = train.replace(to_replace=['Karapakkam','Karapakam'],value='Karapakkam')
train = train.replace(to_replace=['Velachery','Velchery'],value='Velachery')
train = train.replace(to_replace=['TNagar','T Nagar'],value='T Nagar')
train = train.replace(to_replace=['Chrompt','Chrmpet','Chormpet'],value='Chrompet')
train = train.replace(to_replace=['KKNagar','KK Nagar'],value='KK Nagar')

# %%
train.AREA.unique()
# Out:
# array(['Karapakkam', 'Anna Nagar', 'Adyar', 'Velachery', 'Chrompet',
#        'KK Nagar', 'T Nagar'], dtype=object)

# %%
train.SALE_COND.unique()
# Out:
# array(['AbNormal', 'Family', 'Partial', 'AdjLand', 'Normal Sale',
#        'Ab Normal', 'Partiall', 'Adj Land', 'PartiaLl'], dtype=object)

# %%
train = train.replace(to_replace=['AbNormal','Ab Normal'],value='Abnormal')

train = train.replace(to_replace=['Partial','Partiall','PartiaLl'],value='partial')

train = train.replace(to_replace=['Adj Land','AdjLand'],value='Adj Land')

# %%
train.PARK_FACIL.unique()

train = train.replace(to_replace=['Noo','No'],value='No')

# %%
categorical = []
for column in train.columns:
    if train[column].dtype == 'object':
        categorical.append(column)
        
        

len(categorical)
print(categorical)
# Out:
# ['PRT_ID', 'AREA', 'DATE_SALE', 'SALE_COND', 'PARK_FACIL', 'DATE_BUILD', 'BUILDTYPE', 'UTILITY_AVAIL', 'STREET', 'MZZONE']

# %%
train.BUILDTYPE.unique()
# Out:
# array(['Commercial', 'Others', 'Other', 'House', 'Comercial'],
#       dtype=object)

# %%
train = train.replace(to_replace=['Others','Other'],value='Others')
train = train.replace(to_replace=['Comercial'],value='Commercial')

# %%
train.UTILITY_AVAIL.unique()
# Out:
# array(['AllPub', 'ELO', 'NoSewr ', 'NoSeWa', 'All Pub'], dtype=object)

# %%
train = train.replace(to_replace=['NoSeWa','NoSewr','NoSewr','NoSewr '],value='No Sewage')
train = train.replace(to_replace=['AllPub','All Pub'],value='All Pub')

# %%
train.STREET.unique()
# Out:
# array(['Paved', 'Gravel', 'No Access', 'Pavd', 'NoAccess'], dtype=object)

# %%
train = train.replace(to_replace=['Pavd'],value='Paved')
train = train.replace(to_replace=['NoAccess'],value='No Access')

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=train,y=train['AREA'])
plt.title("Area Location")
# Out:
# Text(0.5, 1.0, 'Area Location')

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=train,y=train['SALE_COND'])
plt.title("Sales Condition")
# Out:
# Text(0.5, 1.0, 'Sales Condition')

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=train,y=train['BUILDTYPE'])
plt.title("Build Type")
# Out:
# Text(0.5, 1.0, 'Build Type')

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=train,y=train['STREET'])
plt.title("Street Type")
# Out:
# Text(0.5, 1.0, 'Street Type')

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=train,y=train['STREET'])
plt.title("Street Type")
# Out:
# Text(0.5, 1.0, 'Street Type')

# %% [markdown]
# #Numerical Columns

# %%
train.columns
# Out:
# Index(['PRT_ID', 'AREA', 'INT_SQFT', 'DATE_SALE', 'DIST_MAINROAD', 'N_BEDROOM',
#        'N_BATHROOM', 'N_ROOM', 'SALE_COND', 'PARK_FACIL', 'DATE_BUILD',
#        'BUILDTYPE', 'UTILITY_AVAIL', 'STREET', 'MZZONE', 'QS_ROOMS',
#        'QS_BATHROOM', 'QS_BEDROOM', 'QS_OVERALL', 'REG_FEE', 'COMMIS',
#        'SALES_PRICE'],
#       dtype='object')

# %%
sns.distplot(train['INT_SQFT'])

# %%
sns.distplot(train['DIST_MAINROAD'])

# %%
train['N_BEDROOM'].info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-eee26795ed5d> in <module>()
# ----> 1 train['N_BEDROOM'].info()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'info'

# %%
train['N_BEDROOM'] = train['N_BEDROOM'].astype(int)

# %%
sns.countplot(train['N_BEDROOM'])

# %%
Area_Group = train.groupby(['AREA','MZZONE'])['PRT_ID'].count()
Area_Group=pd.DataFrame(Area_Group)
Area_Group.to_csv("Grouped_Area.csv")

# %%
train.AREA.value_counts()
# Out:
# Chrompet      1702
# Karapakkam    1366
# KK Nagar       997
# Velachery      981
# Anna Nagar     788
# Adyar          774
# T Nagar        501
# Name: AREA, dtype: int64

# %%
train.MZZONE.value_counts()
# Out:
# RL    1858
# RH    1822
# RM    1817
# C      550
# A      537
# I      525
# Name: MZZONE, dtype: int64

# %%
train['N_BEDROOM'].value_counts()
# Out:
# 1    3796
# 2    2352
# 3     707
# 4     254
# Name: N_BEDROOM, dtype: int64

# %%
total_columns = train.columns

# %%
total_columns
# Out:
# Index(['PRT_ID', 'AREA', 'INT_SQFT', 'DATE_SALE', 'DIST_MAINROAD', 'N_BEDROOM',
#        'N_BATHROOM', 'N_ROOM', 'SALE_COND', 'PARK_FACIL', 'DATE_BUILD',
#        'BUILDTYPE', 'UTILITY_AVAIL', 'STREET', 'MZZONE', 'QS_ROOMS',
#        'QS_BATHROOM', 'QS_BEDROOM', 'QS_OVERALL', 'REG_FEE', 'COMMIS',
#        'SALES_PRICE'],
#       dtype='object')

# %%
import plotly.express as px

# %%
px.scatter(train,x='AREA',y='SALES_PRICE')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="acf5c30c-d927-4bc4-8037-b655d86dbd0f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("acf5c30c-d927-4bc4-8037-b655d86dbd0f")) {                    Plotly.newPlot(                        "acf5c30c-d927-4bc4-8037-b655d86dbd0f",                        [{"hovertemplate":"AREA=%{x}<br>SALES_PRICE=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":
965,9822750,5602750,10948060,9343500,13358600,9671160,7871490,6227250,20181980,12402070,6703210,10978140,8388500,14239850,4917940,13940580,12520250,5232500,10416480,9179950,7030720,8636980,11552700,6397000,11119720,18984160,5244500,10094160,13683650,9328250,7581750,12014520,5073500,11718800,7553060,9762100,12370550,16602700,3643875,7766550,8561060,11319280,9721700,9894050,12286360,10008100,16656560,4918500,6688000,8947750,13729040,12477240,9146500,12239160,11670400,11949085,18855250,13668850,6597000,5046750,7060000,6390690,6978025,7384750,9273100,7524750,7102125,9567000,17180560,8078620,7544000,8047500,6125250,11268000,12173800,8539610,5940250,12532900,20734630,8892625,4950250,9507320,7020750,11813720,6465000,11026000,11450470,9692960,7491375,9451250,10044600,10223050,6297250,11110000,6553750,10933000,20550920,6898250,11430420,7541750,6443000,6519000,13533950,5342000,17294550,14209800,13582900,11900750,8798750 ...

# %% [markdown]
# #To finish

# %%
train["SALES_PRICE_LAKHS"] = round(train['SALES_PRICE']/1000000,2)

# %%
train["SALES_PRICE_LAKHS"]
# Out:
# 0        7.60
# 1       21.72
# 2       13.16
# 3        9.63
# 4        7.41
#         ...
# 7104     5.35
# 7105    10.82
# 7106     8.35
# 7107     8.51
# 7108     9.98
# Name: SALES_PRICE_LAKHS, Length: 7109, dtype: float64

# %%
train['N_BATHROOM']=train['N_BATHROOM'].astype(int)
train['N_BEDROOM']=train['N_BEDROOM'].astype(int)

# %%
#averaging data
temp =pd.DataFrame(train.groupby('N_BEDROOM')['SALES_PRICE'].mean())
temp['N_BEDROOM'] = temp.index
temp = temp.sort_values(by='SALES_PRICE',ignore_index=True)
N_BEDROOM_values = temp.N_BEDROOM.unique()

#Ploting
px.bar(temp,y='SALES_PRICE',x='N_BEDROOM',color='N_BEDROOM')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d529c99a-6a7d-4380-bfa0-8728f5c8b432" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d529c99a-6a7d-4380-bfa0-8728f5c8b432")) {                    Plotly.newPlot(                        "d529c99a-6a7d-4380-bfa0-8728f5c8b432",                        [{"alignmentgroup":"True","hovertemplate":"N_BEDROOM=%{marker.color}<br>SALES_PRICE=%{y}<extra></extra>","legendgroup":"","marker":{"color":[1,2,3,4],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[1,2,3,4],"xaxis":"x","y":[9790449.488935722,11817472.880527211,12478131.046676096,14451305.118110236],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewid ...

# %%
#averaging data
temp =pd.DataFrame(train.groupby('N_BATHROOM')['SALES_PRICE'].mean())
temp['N_BATHROOM'] = temp.index
temp = temp.sort_values(by='SALES_PRICE',ignore_index=True)
N_BATHROOM_values = temp.N_BATHROOM.unique()
#Ploting
px.bar(temp,y='SALES_PRICE',x='N_BATHROOM',color='N_BATHROOM')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4c8d4dd0-f235-4bdc-8687-dfc213a2f950" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c8d4dd0-f235-4bdc-8687-dfc213a2f950")) {                    Plotly.newPlot(                        "4c8d4dd0-f235-4bdc-8687-dfc213a2f950",                        [{"alignmentgroup":"True","hovertemplate":"N_BATHROOM=%{marker.color}<br>SALES_PRICE=%{y}<extra></extra>","legendgroup":"","marker":{"color":[1,2],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[1,2],"xaxis":"x","y":[10681476.860922417,11682990.801980197],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatt ...

# %%
#averaging data
temp =pd.DataFrame(train.groupby('N_ROOM')['SALES_PRICE'].mean())
temp['N_ROOM'] = temp.index
temp = temp.sort_values(by='SALES_PRICE',ignore_index=True)
N_ROOM_values = temp.N_ROOM.unique()


#Ploting
px.bar(temp,y='SALES_PRICE',x='N_ROOM',color='N_ROOM')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e6186981-8416-422a-9492-4cb0a950eb28" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e6186981-8416-422a-9492-4cb0a950eb28")) {                    Plotly.newPlot(                        "e6186981-8416-422a-9492-4cb0a950eb28",                        [{"alignmentgroup":"True","hovertemplate":"N_ROOM=%{marker.color}<br>SALES_PRICE=%{y}<extra></extra>","legendgroup":"","marker":{"color":
"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram ...

# %%
#averaging data
temp =pd.DataFrame(train.groupby('PARK_FACIL')['SALES_PRICE'].mean())
temp['PARK_FACIL'] = temp.index
temp = temp.sort_values(by='SALES_PRICE',ignore_index=True)
PARK_FACIL_values = temp.PARK_FACIL.unique()

#Ploting
px.bar(temp,y='SALES_PRICE',x='PARK_FACIL',color='PARK_FACIL')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="70087dc7-cd8a-429d-bdb4-9f35165e630c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("70087dc7-cd8a-429d-bdb4-9f35165e630c")) {                    Plotly.newPlot(                        "70087dc7-cd8a-429d-bdb4-9f35165e630c",                        [{"alignmentgroup":"True","hovertemplate":"PARK_FACIL=%{x}<br>SALES_PRICE=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"textposition":"auto","x":["No"],"xaxis":"x","y":[10338050.350653037],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"PARK_FACIL=%{x}<br>SALES_PRICE=%{y}<extra></extra>","legendgroup":"Yes","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"textposition":"auto","x":["Yes"],"xaxis":"x","y":[11441678.084750488],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour" ...

# %%
#averaging data
temp =pd.DataFrame(train.groupby('BUILDTYPE')['SALES_PRICE'].mean())
temp['BUILDTYPE'] = temp.index
temp = temp.sort_values(by='SALES_PRICE',ignore_index=True)
BUILDTYPE_values = temp.BUILDTYPE.unique()

#Ploting
px.bar(temp,y='SALES_PRICE',x='BUILDTYPE',color='BUILDTYPE')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c8514ea7-6634-4826-a6bb-8aaf2936904e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c8514ea7-6634-4826-a6bb-8aaf2936904e")) {                    Plotly.newPlot(                        "c8514ea7-6634-4826-a6bb-8aaf2936904e",                        [{"alignmentgroup":"True","hovertemplate":"BUILDTYPE=%{x}<br>SALES_PRICE=%{y}<extra></extra>","legendgroup":"House","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"House","offsetgroup":"House","orientation":"v","showlegend":true,"textposition":"auto","x":["House"],"xaxis":"x","y":[9098846.581423895],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"BUILDTYPE=%{x}<br>SALES_PRICE=%{y}<extra></extra>","legendgroup":"Others","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Others","offsetgroup":"Others","orientation":"v","showlegend":true,"textposition":"auto","x":["Others"],"xaxis":"x","y":[9807998.01583904],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"BUILDTYPE=%{x}<br>SALES_PRICE=%{y}<extra></extra>","legendgroup":"Commercial","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Commercial","offsetgroup":"Commercial","orientation":"v","showlegend":true,"textposition":"auto","x":["Commercial"],"xaxis":"x","y":[13869836.073422069],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogr ...

# %%
temp =pd.DataFrame(train.groupby('AREA')['SALES_PRICE'].mean())
temp['AREA'] = temp.index
temp = temp.sort_values(by='SALES_PRICE')
AREA_values = temp.AREA.unique()


px.bar(temp,y='SALES_PRICE')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1caed8d3-9b9b-4c7e-a2c5-9323f64020b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1caed8d3-9b9b-4c7e-a2c5-9323f64020b7")) {                    Plotly.newPlot(                        "1caed8d3-9b9b-4c7e-a2c5-9323f64020b7",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>SALES_PRICE=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Karapakkam","Adyar","Chrompet","Velachery","KK Nagar","Anna Nagar","T Nagar"],"xaxis":"x","y":[7340100.109809663,9185668.391472869,10013809.64747356,11047353.027522936,12696228.746238716,15168201.9035533,15616742.59481038],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pi ...

# %%
train.columns
# Out:
# Index(['PRT_ID', 'AREA', 'INT_SQFT', 'DATE_SALE', 'DIST_MAINROAD', 'N_BEDROOM',
#        'N_BATHROOM', 'N_ROOM', 'SALE_COND', 'PARK_FACIL', 'DATE_BUILD',
#        'BUILDTYPE', 'UTILITY_AVAIL', 'STREET', 'MZZONE', 'QS_ROOMS',
#        'QS_BATHROOM', 'QS_BEDROOM', 'QS_OVERALL', 'REG_FEE', 'COMMIS',
#        'SALES_PRICE', 'Year Sale', 'Year Build', 'SALES_PRICE_LAKHS'],
#       dtype='object')

# %%
#averaging data
temp =pd.DataFrame(train.groupby('INT_SQFT')['SALES_PRICE'].mean())
temp['INT_SQFT'] = temp.index
temp = temp.sort_values(by='SALES_PRICE',ignore_index=True)

#Ploting
px.histogram(temp,y='SALES_PRICE',x='INT_SQFT',nbins=25)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9ce8c179-a942-4524-9824-eb122c3867f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9ce8c179-a942-4524-9824-eb122c3867f6")) {                    Plotly.newPlot(                        "9ce8c179-a942-4524-9824-eb122c3867f6",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"INT_SQFT=%{x}<br>sum of SALES_PRICE=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":25,"offsetgroup":"","orientation":"v","showlegend":false,"x":
columns
# Out:
# Index(['PRT_ID', 'AREA', 'INT_SQFT', 'DATE_SALE', 'DIST_MAINROAD', 'N_BEDROOM',
#        'N_BATHROOM', 'N_ROOM', 'SALE_COND', 'PARK_FACIL', 'DATE_BUILD',
#        'BUILDTYPE', 'UTILITY_AVAIL', 'STREET', 'MZZONE', 'QS_ROOMS',
#        'QS_BATHROOM', 'QS_BEDROOM', 'QS_OVERALL', 'REG_FEE', 'COMMIS',
#        'SALES_PRICE', 'Year Sale', 'Year Build', 'SALES_PRICE_LAKHS'],
#       dtype='object')

# %%
#averaging data
temp =pd.DataFrame(train.groupby('SALE_COND')['SALES_PRICE'].mean())
temp['SALE_COND'] = temp.index
temp = temp.sort_values(by='SALES_PRICE',ignore_index=True)
SALE_COND_values = temp.SALE_COND.unique()

#Ploting
px.bar(temp,y='SALES_PRICE',x='SALE_COND',color='SALE_COND')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8561eeb3-f90f-47aa-9e29-64ed79c3f030" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8561eeb3-f90f-47aa-9e29-64ed79c3f030")) {                    Plotly.newPlot(                        "8561eeb3-f90f-47aa-9e29-64ed79c3f030",                        [{"alignmentgroup":"True","hovertemplate":"SALE_COND=%{x}<br>SALES_PRICE=%{y}<extra></extra>","legendgroup":"partial","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"partial","offsetgroup":"partial","orientation":"v","showlegend":true,"textposition":"auto","x":["partial"],"xaxis":"x","y":[10616369.351011863],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"SALE_COND=%{x}<br>SALES_PRICE=%{y}<extra></extra>","legendgroup":"Family","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Family","offsetgroup":"Family","orientation":"v","showlegend":true,"textposition":"auto","x":["Family"],"xaxis":"x","y":[10736415.498930862],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"SALE_COND=%{x}<br>SALES_PRICE=%{y}<extra></extra>","legendgroup":"Abnormal","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Abnormal","offsetgroup":"Abnormal","orientation":"v","showlegend":true,"textposition":"auto","x":["Abnormal"],"xaxis":"x","y":[10914631.562721474],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"SALE_COND=%{x}<br>SALES_PRICE=%{y}<extra></extra>","legendgroup":"Normal Sale","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Normal Sale","offsetgroup":"Normal Sale","orientation":"v","showlegend":true,"textposition":"auto","x":["Normal Sale"],"xaxis":"x","y":[10994177.803935347],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"SALE_COND=%{x}<br>SALES_PRICE=%{y}<extra></extra>","legendgroup":"Adj Land","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Adj Land","offsetgroup":"Adj Land","orientation":"v","showlegend":true,"textposition":"auto","x":["Adj Land"],"xaxis":"x","y":[11209314.975677554],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#720 ...

# %%
#averaging data
temp =pd.DataFrame(train.groupby('UTILITY_AVAIL')['SALES_PRICE'].mean())
temp['UTILITY_AVAIL'] = temp.index
temp = temp.sort_values(by='SALES_PRICE',ignore_index=True)
UTILITY_AVAIL_values = temp.UTILITY_AVAIL.unique()

#Ploting
px.bar(temp,y='SALES_PRICE',x='UTILITY_AVAIL',color='UTILITY_AVAIL')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7dd6d28c-3950-4746-8fb9-a7c1ca781fe6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7dd6d28c-3950-4746-8fb9-a7c1ca781fe6")) {                    Plotly.newPlot(                        "7dd6d28c-3950-4746-8fb9-a7c1ca781fe6",                        [{"alignmentgroup":"True","hovertemplate":"UTILITY_AVAIL=%{x}<br>SALES_PRICE=%{y}<extra></extra>","legendgroup":"ELO","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"ELO","offsetgroup":"ELO","orientation":"v","showlegend":true,"textposition":"auto","x":["ELO"],"xaxis":"x","y":[10469414.625492772],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"UTILITY_AVAIL=%{x}<br>SALES_PRICE=%{y}<extra></extra>","legendgroup":"No Sewage","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"No Sewage","offsetgroup":"No Sewage","orientation":"v","showlegend":true,"textposition":"auto","x":["No Sewage"],"xaxis":"x","y":[10909233.547297297],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"UTILITY_AVAIL=%{x}<br>SALES_PRICE=%{y}<extra></extra>","legendgroup":"All Pub","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"All Pub","offsetgroup":"All Pub","orientation":"v","showlegend":true,"textposition":"auto","x":["All Pub"],"xaxis":"x","y":[11210015.601483837],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}]," ...

# %%
#averaging data
temp =pd.DataFrame(train.groupby('STREET')['SALES_PRICE'].mean())
temp['STREET'] = temp.index
temp = temp.sort_values(by='SALES_PRICE',ignore_index=True)
STREET_values = temp.STREET.unique()


#Ploting
px.bar(temp,y='SALES_PRICE',x='STREET',color='STREET')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="be70fd25-102b-4940-bb37-31d033a421bb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be70fd25-102b-4940-bb37-31d033a421bb")) {                    Plotly.newPlot(                        "be70fd25-102b-4940-bb37-31d033a421bb",                        [{"alignmentgroup":"True","hovertemplate":"STREET=%{x}<br>SALES_PRICE=%{y}<extra></extra>","legendgroup":"No Access","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No Access","offsetgroup":"No Access","orientation":"v","showlegend":true,"textposition":"auto","x":["No Access"],"xaxis":"x","y":[10000738.430837879],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"STREET=%{x}<br>SALES_PRICE=%{y}<extra></extra>","legendgroup":"Paved","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Paved","offsetgroup":"Paved","orientation":"v","showlegend":true,"textposition":"auto","x":["Paved"],"xaxis":"x","y":[11057536.708786936],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"STREET=%{x}<br>SALES_PRICE=%{y}<extra></extra>","legendgroup":"Gravel","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Gravel","offsetgroup":"Gravel","orientation":"v","showlegend":true,"textposition":"auto","x":["Gravel"],"xaxis":"x","y":[11444618.569444444],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontou ...

# %%
#averaging data
temp =pd.DataFrame(train.groupby('MZZONE')['SALES_PRICE'].mean())
temp['MZZONE'] = temp.index
temp = temp.sort_values(by='SALES_PRICE',ignore_index=True)


#Ploting
px.bar(temp,y='SALES_PRICE',x='MZZONE',color='MZZONE')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="dfdbfba2-a3bf-4c75-a889-4322ffa4cbac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dfdbfba2-a3bf-4c75-a889-4322ffa4cbac")) {                    Plotly.newPlot(                        "dfdbfba2-a3bf-4c75-a889-4322ffa4cbac",                        [{"alignmentgroup":"True","hovertemplate":"MZZONE=%{x}<br>SALES_PRICE=%{y}<extra></extra>","legendgroup":"A","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"A","offsetgroup":"A","orientation":"v","showlegend":true,"textposition":"auto","x":["A"],"xaxis":"x","y":[7292591.080074488],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"MZZONE=%{x}<br>SALES_PRICE=%{y}<extra></extra>","legendgroup":"C","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"C","offsetgroup":"C","orientation":"v","showlegend":true,"textposition":"auto","x":["C"],"xaxis":"x","y":[8052270.172727273],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"MZZONE=%{x}<br>SALES_PRICE=%{y}<extra></extra>","legendgroup":"I","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"I","offsetgroup":"I","orientation":"v","showlegend":true,"textposition":"auto","x":["I"],"xaxis":"x","y":[8738632.723809524],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"MZZONE=%{x}<br>SALES_PRICE=%{y}<extra></extra>","legendgroup":"RH","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"RH","offsetgroup":"RH","orientation":"v","showlegend":true,"textposition":"auto","x":["RH"],"xaxis":"x","y":[11039971.550493963],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"MZZONE=%{x}<br>SALES_PRICE=%{y}<extra></extra>","legendgroup":"RL","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"RL","offsetgroup":"RL","orientation":"v","showlegend":true,"textposition":"auto","x":["RL"],"xaxis":"x","y":[11765762.54305705],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"MZZONE=%{x}<br>SALES_PRICE=%{y}<extra></extra>","legendgroup":"RM","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"RM","offsetgroup":"RM","orientation":"v","showlegend":true,"textposition":"auto","x":["RM"],"xaxis":"x","y":[12407069.603742432],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0 ...

# %%
Mzzone_values = temp.MZZONE.unique()
Mzzone_values
# Out:
# array(['A', 'C', 'I', 'RH', 'RL', 'RM'], dtype=object)

# %%
train['MZZONE'].unique()
# Out:
# array(['A', 'RH', 'RL', 'I', 'C', 'RM'], dtype=object)

# %%
train.drop(['PRT_ID','QS_ROOMS','QS_BATHROOM','QS_BEDROOM','QS_OVERALL'],axis=1,inplace=True)

# %% [markdown]
# #Cleaned Csv File Export

# %%
train.to_csv('cleaned.csv')
print("Cleaned Data Exported sucessfuly as cleaned.csv")
print("***********************************************")
# Out:
# Cleaned Data Exported sucessfuly as cleaned.csv
# ***********************************************

# %% [markdown]
# #Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder

# %%
train.columns
# Out:
# Index(['AREA', 'INT_SQFT', 'DATE_SALE', 'DIST_MAINROAD', 'N_BEDROOM',
#        'N_BATHROOM', 'N_ROOM', 'SALE_COND', 'PARK_FACIL', 'DATE_BUILD',
#        'BUILDTYPE', 'UTILITY_AVAIL', 'STREET', 'MZZONE', 'REG_FEE', 'COMMIS',
#        'SALES_PRICE', 'Year Sale', 'Year Build', 'SALES_PRICE_LAKHS'],
#       dtype='object')

# %%
train['MZZONE']=train['MZZONE'].replace(to_replace=Mzzone_values,value=[1,2,3,4,5,6])

train['STREET']=train['STREET'].replace(to_replace=STREET_values,value=[1,2,3])

train['AREA']=train['AREA'].replace(to_replace=AREA_values,value=[1,2,3,4,5,6,7])

train['N_BEDROOM']=train['N_BEDROOM'].replace(to_replace=N_BEDROOM_values,value=[1,2,3,4])

train['N_BATHROOM']=train['N_BATHROOM'].replace(to_replace=N_BATHROOM_values,value=[1,2])

train['SALE_COND']=train['SALE_COND'].replace(to_replace=SALE_COND_values,value=[1,2,3,4,5])

train['PARK_FACIL']=train['PARK_FACIL'].replace(to_replace=PARK_FACIL_values,value=[1,2])

train['BUILDTYPE']=train['BUILDTYPE'].replace(to_replace=BUILDTYPE_values,value=[1,2,3])

train['UTILITY_AVAIL']=train['UTILITY_AVAIL'].replace(to_replace=UTILITY_AVAIL_values,value=[1,2,3])

# %% [markdown]
# Label Encoder
#
#
# for column in train.columns: if train[column].dtype == object: train[column] = le.fit_transform(train[column])

# %%
from sklearn.model_selection import train_test_split

# %%
X = train.drop(['SALES_PRICE','SALES_PRICE_LAKHS','DATE_SALE','DATE_BUILD','REG_FEE','COMMIS'],axis=1)
Y = train.SALES_PRICE

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=124)

# %%
from sklearn import feature_selection

# %%
orginalfeatures = train.columns
print("Orginal Features Count : ",len(orginalfeatures))
# Out:
# Orginal Features Count :  20

# %%
plt.figure(figsize=(20,20))
cor = x_train.corr()
sns.heatmap(cor,annot=True,square=True,cmap=plt.cm.CMRmap_r)
plt.show()

# %%
def correlation(dataset,threshold):
    col_corr =set()
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j]) > threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(x_test,0.9)

# %%
len(corr_features)
# Out:
# 1

# %%
corr_features
# Out:
# {'N_ROOM'}

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import r_regression

# %%
x_train
# Out:
#       AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  N_ROOM  SALE_COND  \
# 3169     2       968             27          1           1       3          3
# 3591     7      1695            194          1           1       4          5
# 2400     2      1159            140          1           1       3          4
# 3281     5      1350             63          2           1       4          2
# 4814     6      1536            191          1           1       4          2
# ...    ...       ...            ...        ...         ...     ...        ...
# 962      4      1845             45          3           2       5          1
# 135      3       711            116          1           1       2          5
# 6161     2      1150            170          1           1       3          2
# 4764     6      1956             64          2           1       5          5
# 4558     6      1538             48          1           1       4          3
#
#       PARK_FACIL  BUILDTYPE  UTILITY_AVAIL  STREET  MZZONE  Year Sale  \
# 3169           2          3              3       2       6       2007
# 3591           2          1              2       3       4       2006
# 2400           2          1              3       3       5       2008
# 3281           2          3              2       2       6       2011
# 4814           1          2              2       3       5       2014
# ...          ...        ...            ...     ...     ...        ...
# 962            2          2              2       3       4       2005
# 135            2          2              2       1       5       2014
# 6161           1          3              1       1       3       2011
# 4764           1          2              2       2       5       2011
# 4558           1          2              3       2       6       2008
#
#       Year Build
# 3169        1979
# 3591        1984
# 2400        1968
# 3281        1992
# 4814        1996
# ...          ...
# 962         1982
# 135         2002
# 6161        1999
# 4764        1983
# 4558        1966
#
# [5687 rows x 14 columns]

# %%
sel = SelectKBest(r_regression,k=2)

# %% [markdown]
# #Machine Learning Models
# Lasso Regression

# %%
from sklearn.linear_model import Lasso

# %%
#fitting the model
lasso = Lasso()
lasso.fit(x_train,y_train)


#predicting the model
ypred = lasso.predict(x_test)
lasso_score = lasso.score(x_test,y_test)*100
print("Lasso Regression score is ",lasso_score)
# Out:
# Lasso Regression score is  88.33949930894848

# %% [markdown]
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(x_train,y_train)

#predicting

ypred = lr.predict(x_test)
lr.score(x_test,y_test)*100
# Out:
# 88.33950357033696

# %% [markdown]
# Ridge Regression

# %%
from sklearn.linear_model import Ridge

# %%
ridge = Ridge()
ridge.fit(x_train,y_train)


#predicting the model
ypred = ridge.predict(x_test)
ridge_score = ridge.score(x_test,y_test)*100
print("Ridge Regression score is ",ridge_score)
# Out:
# Ridge Regression score is  88.33970033544645

# %% [markdown]
# DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
#fitting the model
decisiontree = DecisionTreeRegressor()
decisiontree.fit(x_train,y_train)

#predicting 
decisiontree_score = decisiontree.score(x_test,y_test)*100
print("Decision Tree score is",decisiontree_score)
# Out:
# Decision Tree score is 96.95313010813716

# %% [markdown]
# RandomForest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
#Fitting the model
randomforest = RandomForestRegressor(max_depth=16,n_estimators=180,random_state=15)
randomforest.fit(x_train,y_train)

ypred = randomforest.predict(x_test)
randomforestscore = randomforest.score(x_test,y_test)*100
print("Random Forest Square is  :",randomforestscore)
# Out:
# Random Forest Square is  : 98.8021367864969

# %% [markdown]
# Gradient Booster

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import accuracy_score

#fitting the model
GradientBoosting = GradientBoostingRegressor()
GradientBoosting.fit(x_train,y_train)

#predicting the model
GradientBoosting_score = GradientBoosting.score(x_test,y_test)*100
GradientBoosting_score
# Out:
# 99.09868917508471

# %% [markdown]
# AdaBoost

# %%
from sklearn.ensemble import AdaBoostRegressor
#fitting the model
adaboost = AdaBoostRegressor(random_state=15,n_estimators=130)
adaboost.fit(x_train,y_train)

#predicting the model
adaboostscore = adaboost.score(x_test,y_test)*100
adaboostscore
# Out:
# 92.95684459502381

# %% [markdown]
# Model Scores

# %%
print("Lasso Regression score is ",lasso_score)
print("Ridge Regression score is ",ridge_score)
print("Decision Tree score is ",decisiontree_score)
print("RandomForest Regression score is ",randomforestscore)
print("Adaboost Regression score is ",adaboostscore)
print("Gradient Boost Regression score is ",GradientBoosting_score)
# Out:
# Lasso Regression score is  88.33949930894848
# Ridge Regression score is  88.33970033544645
# Decision Tree score is  96.95313010813716
# RandomForest Regression score is  98.8021367864969
# Adaboost Regression score is  92.95684459502381
# Gradient Boost Regression score is  99.09868917508471

# %%
## Ploting the randomforest
plt.figure(figsize=(25,5))
x_ax = range(len(y_test))
plt.plot(x_ax,y_test,label='orginal')
plt.plot(x_ax,ypred,label='predicted')
plt.legend(loc='best',fancybox=True,shadow=True)
#plt.grid(True)
plt.show()

# %%
x_train
# Out:
#       AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  N_ROOM  SALE_COND  \
# 3169     2       968             27          1           1       3          3
# 3591     7      1695            194          1           1       4          5
# 2400     2      1159            140          1           1       3          4
# 3281     5      1350             63          2           1       4          2
# 4814     6      1536            191          1           1       4          2
# ...    ...       ...            ...        ...         ...     ...        ...
# 962      4      1845             45          3           2       5          1
# 135      3       711            116          1           1       2          5
# 6161     2      1150            170          1           1       3          2
# 4764     6      1956             64          2           1       5          5
# 4558     6      1538             48          1           1       4          3
#
#       PARK_FACIL  BUILDTYPE  UTILITY_AVAIL  STREET  MZZONE  Year Sale  \
# 3169           2          3              3       2       6       2007
# 3591           2          1              2       3       4       2006
# 2400           2          1              3       3       5       2008
# 3281           2          3              2       2       6       2011
# 4814           1          2              2       3       5       2014
# ...          ...        ...            ...     ...     ...        ...
# 962            2          2              2       3       4       2005
# 135            2          2              2       1       5       2014
# 6161           1          3              1       1       3       2011
# 4764           1          2              2       2       5       2011
# 4558           1          2              3       2       6       2008
#
#       Year Build
# 3169        1979
# 3591        1984
# 2400        1968
# 3281        1992
# 4814        1996
# ...          ...
# 962         1982
# 135         2002
# 6161        1999
# 4764        1983
# 4558        1966
#
# [5687 rows x 14 columns]

# %%
#Feature importance
feature_scores = pd.Series(randomforest.feature_importances_,index=x_train.columns).sort_values(ascending=False)
feature_scores=feature_scores*100
feature_scores
# Out:
# AREA             47.409561
# BUILDTYPE        33.157000
# INT_SQFT         11.063281
# MZZONE            3.756751
# PARK_FACIL        1.525159
# STREET            1.049444
# Year Build        0.481964
# N_ROOM            0.415392
# DIST_MAINROAD     0.249568
# N_BATHROOM        0.239732
# SALE_COND         0.239726
# N_BEDROOM         0.181135
# Year Sale         0.140900
# UTILITY_AVAIL     0.090389
# dtype: float64

# %%
plt.figure(figsize=(12,12))
sns.barplot(x=feature_scores,y=feature_scores.index)
plt.show()

# %%
plt.figure(figsize=(25,5))
x_ax = range(len(y_test))
plt.plot(x_ax,y_test,label='orginal')
plt.plot(x_ax,ypred,label='predicted')
plt.legend(loc='best',fancybox=True,shadow=True)
#plt.grid(True)
plt.show()

# %%
feature_scores
# Out:
# AREA             47.409561
# BUILDTYPE        33.157000
# INT_SQFT         11.063281
# MZZONE            3.756751
# PARK_FACIL        1.525159
# STREET            1.049444
# Year Build        0.481964
# N_ROOM            0.415392
# DIST_MAINROAD     0.249568
# N_BATHROOM        0.239732
# SALE_COND         0.239726
# N_BEDROOM         0.181135
# Year Sale         0.140900
# UTILITY_AVAIL     0.090389
# dtype: float64

# %%
main_features = feature_scores.loc[feature_scores > 0]
main_features
# Out:
# AREA             47.409561
# BUILDTYPE        33.157000
# INT_SQFT         11.063281
# MZZONE            3.756751
# PARK_FACIL        1.525159
# STREET            1.049444
# Year Build        0.481964
# N_ROOM            0.415392
# DIST_MAINROAD     0.249568
# N_BATHROOM        0.239732
# SALE_COND         0.239726
# N_BEDROOM         0.181135
# Year Sale         0.140900
# UTILITY_AVAIL     0.090389
# dtype: float64

# %%
train.columns
# Out:
# Index(['AREA', 'INT_SQFT', 'DATE_SALE', 'DIST_MAINROAD', 'N_BEDROOM',
#        'N_BATHROOM', 'N_ROOM', 'SALE_COND', 'PARK_FACIL', 'DATE_BUILD',
#        'BUILDTYPE', 'UTILITY_AVAIL', 'STREET', 'MZZONE', 'REG_FEE', 'COMMIS',
#        'SALES_PRICE', 'Year Sale', 'Year Build', 'SALES_PRICE_LAKHS'],
#       dtype='object')

# %%
main_features = ['AREA','INT_SQFT','N_BEDROOM','PARK_FACIL','MZZONE','BUILDTYPE','STREET']

# %%
X = train[main_features]

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=15)

# %% [markdown]
# #Finalized Model

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import accuracy_score

#fitting the model
GradientBoosting = GradientBoostingRegressor()
GradientBoosting.fit(x_train,y_train)

#predicting the model
GradientBoosting_score = GradientBoosting.score(x_test,y_test)*100
GradientBoosting_score
# Out:
# 98.68264932247797

# %%
GradientBoosting.predict([[659,1,3,4,1,2,2]])
# Out:
# array([9139027.38244865])

# %%
#Currency Conversion
from babel.numbers import format_currency

# %%
valu=GradientBoosting.predict([[1500,1,2,3,2,1,2]])
low=int(valu-(valu*0.01))
low = format_currency(low, 'INR', locale='en_IN')



high=int(valu+(valu*0.01))
high = format_currency(high, 'INR', locale='en_IN')
print('Estimated value is:',low , 'to', high)
# Out:
# Estimated value is: ₹91,04,533.00 to ₹92,88,463.00
